# %%
import numpy as np
import itertools

from konlpy.tag import Kkma, Komoran, Hannanum, Okt
from konlpy.utils import pprint
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       6 from sklearn.feature_extraction.text import CountVectorizer
#       7 from sklearn.metrics.pairwise import cosine_similarity
# ----> 8 from sentence_transformers import SentenceTransformer
#
# File ~\anaconda3\lib\site-packages\sentence_transformers\__init__.py:3
#       1 __version__ = "2.2.0"
#       2 __MODEL_HUB_ORGANIZATION__ = 'sentence-transformers'
# ----> 3 from .datasets import SentencesDataset, ParallelSentencesDataset
#       4 from .LoggingHandler import LoggingHandler
#       5 from .SentenceTransformer import SentenceTransformer
#
# File ~\anaconda3\lib\site-packages\sentence_transformers\datasets\__init__.py:3
#       1 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ----> 3 from .ParallelSentencesDataset import ParallelSentencesDataset
#       4 from .SentencesDataset import SentencesDataset
#       5 from .SentenceLabelDataset import SentenceLabelDataset
#
# File ~\anaconda3\lib\site-packages\sentence_transformers\datasets\ParallelSentencesDataset.py:4
#       2 import logging
#       3 import gzip
# ----> 4 from .. import SentenceTransformer
#       5 from ..readers import InputExample
#       6 from typing import List
#
# File ~\anaconda3\lib\site-packages\sentence_transformers\SentenceTransformer.py:25
#      22 from distutils.dir_util import copy_tree
#      24 from . import __MODEL_HUB_ORGANIZATION__
# ---> 25 from .evaluation import SentenceEvaluator
#      26 from .util import import_from_string, batch_to_device, fullname, snapshot_download
#      27 from .models import Transformer, Pooling, Dense
#
# File ~\anaconda3\lib\site-packages\sentence_transformers\evaluation\__init__.py:5
#       3 from .BinaryClassificationEvaluator import BinaryClassificationEvaluator
#       4 from .EmbeddingSimilarityEvaluator import EmbeddingSimilarityEvaluator
# ----> 5 from .InformationRetrievalEvaluator import InformationRetrievalEvaluator
#       6 from .LabelAccuracyEvaluator import LabelAccuracyEvaluator
#       7 from .MSEEvaluator import MSEEvaluator
#
# File ~\anaconda3\lib\site-packages\sentence_transformers\evaluation\InformationRetrievalEvaluator.py:6
#       4 import logging
#       5 from tqdm import tqdm, trange
# ----> 6 from ..util import cos_sim, dot_score
#       7 import os
#       8 import numpy as np
#
# File ~\anaconda3\lib\site-packages\sentence_transformers\util.py:407
#     405 from huggingface_hub.constants import HUGGINGFACE_HUB_CACHE
#     406 from huggingface_hub import HfApi, hf_hub_url, cached_download
# --> 407 from huggingface_hub.snapshot_download import REPO_ID_SEPARATOR
#     408 import fnmatch
#     410 def snapshot_download(
#     411     repo_id: str,
#     412     revision: Optional[str] = None,
#    (...)
#     418     use_auth_token: Union[bool, str, None] = None
#     419 ) -> str:
#
# File ~\anaconda3\lib\site-packages\huggingface_hub\snapshot_download.py:23
#      15 # ^ this substring is not allowed in repo_ids on hf.co
#      16 # and is the canonical one we use for serialization of repo ids elsewhere.
#      19 logger = logging.get_logger(__name__)
#      22 @_deprecate_positional_args
# ---> 23 def snapshot_download(
#      24     repo_id: str,
#      25     *,
#      26     revision: Optional[str] = None,
#      27     cache_dir: Union[str, Path, None] = None,
#      28     library_name: Optional[str] = None,
#      29     library_version: Optional[str] = None,
#      30     user_agent: Optional[Union[Dict, str]] = None,
#      31     proxies: Optional[Dict] = None,
#      32     etag_timeout: Optional[float] = 10,
#      33     resume_download: Optional[bool] = False,
#      34     use_auth_token: Optional[Union[bool, str]] = None,
#      35     local_files_only: Optional[bool] = False,
#      36     allow_regex: Optional[Union[List[str], str]] = None,
#      37     ignore_regex: Optional[Union[List[str], str]] = None,
#      38 ) -> str:
#      39     """Download all files of a repo.
#      40
#      41     Downloads a whole snapshot of a repo's files at the specified revision. This
#    (...)
#      98     </Tip>
#      99     """
#     100     # Note: at some point maybe this format of storage should actually replace
#     101     # the flat storage structure we've used so far (initially from allennlp
#     102     # if I remember correctly).
#
# TypeError: _deprecate_positional_args() takes 0 positional arguments but 1 was given

# %%
import pandas as pd

# %%
data = pd.read_csv("./fivecart_2020.csv", encoding='cp949')
data.head(5)
# Out:
#   report_writer date_writer                                            title  \
# 0           박유담  2022-05-02                                              군주론
# 1            백석  2022-04-17  빛 속으로 (한국 문학사에서 지워진 이름. 평생을 방랑자로 산 작가 김사량의 작품집)
# 2         maobi  2022-04-16                               작별하지 않는다 (한강 장편소설)
# 3          킹고선비  2022-04-10                               나의 한국현대사 1959-2020
# 4          nama  2022-04-08                        그냥 하지 말라 (당신의 모든 것이 메시지다)
#
#   book_writer book_company   book_date  \
# 0       마키아벨리         현대지성  2021-07-26
# 1         김사량         녹색광선  2021-08-15
# 2          한강         문학동네  2021-09-09
# 3         유시민          돌베개  2021-01-20
# 4         송길영          북스톤  2021-10-05
#
#                                          report_text
# 0     마키아벨리의 군주론을 읽고21세기를 살아가고 있는 우리에게 리더의 역할은 더욱...
# 1     <비뚤어진 우월감>  우리는 때때로 자신의 치부로 울타리를 두르고 그 안에 갇...
# 2      다시 한강 작가님의 책을 읽을 때까지는 고민이 있었다. '소년이 온다'를 읽...
# 3     59년생 ‘68세대’의 회고록을 읽은 97년생 ‘MZ세대’의 감상문    몇 ...
# 4     저자는 과거부터 현재까지 변화해온, 또 앞으로 변화할 한국사회를 데이터를 통해...

# %%
data
# Out:
#     report_writer date_writer  \
# 0             박유담  2022-05-02
# 1              백석  2022-04-17
# 2           maobi  2022-04-16
# 3            킹고선비  2022-04-10
# 4            nama  2022-04-08
# ..            ...         ...
# 350       aowoekd  2013-01-28
# 351           꽃향유  2012-12-31
# 352          사사로움  2010-09-27
# 353        seonv1  2010-05-07
# 354          두르두르  2009-12-02
#
#                                                  title     book_writer  \
# 0                                                  군주론           마키아벨리
# 1      빛 속으로 (한국 문학사에서 지워진 이름. 평생을 방랑자로 산 작가 김사량의 작품집)             김사량
# 2                                   작별하지 않는다 (한강 장편소설)              한강
# 3                                   나의 한국현대사 1959-2020             유시민
# 4                            그냥 하지 말라 (당신의 모든 것이 메시지다)             송길영
# ..                                                 ...             ...
# 350                                       죄와 벌.상 하 상 하          도스토옙스키
# 351                                           세계의 공익광고        카네코 히데유키
# 352                                         귤이 탱자가된 이유            동화사랑
# 353  Communication Technology&Society: Audience Ado...  Lin|Carolyn A.
# 354                                         삶의 의미를 찾아서             유챙롱
#
#     book_company   book_date  \
# 0           현대지성  2021-07-26
# 1           녹색광선  2021-08-15
# 2           문학동네  2021-09-09
# 3            돌베개  2021-01-20
# 4            북스톤  2021-10-05
# ..           ...         ...
# 350         열린책들  2022-05-03
# 351  한국방송공사출판사업부  2022-05-03
# 352          글뿌리  2022-05-04
# 353          티메카  2022-05-04
# 354    창작미디어(만화)  2022-05-04
#
#                                            report_text
# 0       마키아벨리의 군주론을 읽고21세기를 살아가고 있는 우리에게 리더의 역할은 더욱...
# 1       <비뚤어진 우월감>  우리는 때때로 자신의 치부로 울타리를 두르고 그 안에 갇...
# 2        다시 한강 작가님의 책을 읽을 때까지는 고민이 있었다. '소년이 온다'를 읽...
# 3       59년생 ‘68세대’의 회고록을 읽은 97년생 ‘MZ세대’의 감상문    몇 ...
# 4       저자는 과거부터 현재까지 변화해온, 또 앞으로 변화할 한국사회를 데이터를 통해...
# ..                                                 ...
# 350     중학교 때 학교 선생님의 추천을 받고 책을 빌렸었는데 그 당시에는 책이 지루해...
# 351     세계의 공익 광고. 공익 광고는 꽤나 적나라하고, 충격 또한 깊게 느낄 수 있...
# 352       봉사활동을 하러 갔다가 우연히 읽은 이 동화책. 사실 이 동화는 정말 뻔한...
# 353     I read this book, I have some points that w...
# 354     [책나눔] 니체 曰 " 왜 사는지 아는 사람은 '어떤' 고난도 이겨낼 수 있다...
#
# [355 rows x 7 columns]

# %%
doc = data['report_text'][4]
doc
# Out:
# '   저자는 과거부터 현재까지 변화해온, 또 앞으로 변화할 한국사회를 데이터를 통해 들여다보고 이야기한다. 비슷한 결의 책을 여러 권 읽어봤지만 단순히 현상만 나열하는 게 아니라 저자의 통찰이 깊게 느껴진 책은 정말 오랜만이었다. 그러면서도 어렵지 않게 쓴다는 것이 대단하다고 생각했다. 세상에 똑똑한 사람은 정말 많지만 어려운 이야기를 이해하기 쉽게 전달하는 능력을 가진 사람은 그리 많지 않은 것 같다. 그래서 더 반갑고 좋았다.  이 책은 변화하는 사회를 살아가기 위해 사회구성원 개개인이 취해야 할 자세를 제시한다. 젊은 세대가 읽어도 좋지만 특히 관리자층이 이 책을 읽어봤으면 하는 바람이다. 중간관리자들의 무능과 고집을 날카롭게 지적하는 부분이 많았다. 나는 아직 사회생활을 제대로 시작해보지 않았지만 가족, 친구들과 대화하다보면 꼭 일도 못하면서 남에게 책임만 전가하는 상사 얘기가 나온다. 나는 이런 어른이 되지는 말아야지. 스스로를 경계하기 위해서도 한 번쯤 읽어보면 좋을 책이다. 중간중간 뜨끔하는 문장이 있을 수도 있다.[당신의 모든 것이 메시지다]책의 부제이기도 한 이 챕터가 가장 인상적이었다. 요즘 들어 기록의 중요성을 점점 체감하고 있다. 개인적으로 기억하기 위함도 있지만 어딘가에 내가 한 활동들과 내 생각을 보여줘야할 때 특히 더 절실히 느낀다. 지금까지는 그걸 기록해야 한다는 생각을 못했는데 이제 와서 정리하려고 보니 내가 했던 게 뭔지, 그걸 통해 뭘 배우고 느꼈는지 잘 기억이 안 나서 막막했다. 그제서야 어떤 형태로든 기록을 해야겠구나 싶었다. 이제 더는 학벌이나 성적이 나를 증명해주지 않는다. 요즘 들어 그걸 정말 많이 느끼고 있고, 앞으로는 세상이 더욱 그런 방향으로 변해갈 것이라 생각한다.저자는 일상의 모든 기록들이 자신을 표현하는 메시지가 된다고 말한다. 이력서나 포트폴리오로 자신을 소개하는 것을 넘어 이제는 소비로도, sns관계망으도 나를 표현하는 시대가 온 것이다. 사람들은 이제 필요에 의해 구매하는 물질소비가 아닌, 자신의 개성을 드러내고 의미를 표현하기 위한 의미소비를 한다. 나 또한 요즘 들어 소비 패턴이 이런 식으로 변하고 있다. 같은 물건이더라도 브랜드가 추구하는 가치가 내가 지향하는 바와 맞는 경우에는 더 즐거운 마음으로 소비를 하게 되고 해당 브랜드를 기억하게 되는 것 같다.콘텐츠 소비 또한 마찬가지로 내가 어떤 콘텐츠를 선택하느냐는 곧 나의 취향을 은연중에 알리는 것과도 같다. 나의 sns에서 누구를 팔로우하느냐도 나의 관심사와 네트워크를 공개하는 행위의 일종인 셈이다. 저자는 결국 이 모든 것이 수렴된 나의 라이프스타일, 나의 모든 것이 메시지가 된다고 말하고 있다.한편으로는 나의 모든 기록이 나를 보여주는 수단이 된다는 게 조금 숨막히기도 하고 무섭게 느껴지기도 한다. 비밀이 없는 사회가 되어가고 있는 것 같다. 나는 지금까지 현실에 안주하며 변화를 두려워하고 거부해왔다. 어쩌면 나는 그 변화에 해당되지 않을 거라고 생각했던 것 같기도 하다. 그러나 저자가 서문에서 이야기했듯이 아직 나에게 일어나지 않았다 해도 변화는 분명히 일어나고 있다. 언젠가는 나에게도 올 그 변화를 맞이할 준비를 해야할 것이다. 모든 것에 장단점이 있듯이 새로운 세상의 장점도 분명히 있을테니 조금은 덜 무서워해도 되지 않을까?   '

# %%
hannanum = Hannanum()

tokenized_doc = hannanum.pos(doc)
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] == 'N'])

print('품사 태깅 10개만 출력 :',tokenized_doc[:10])
print('명사 추출 :',tokenized_nouns)
# Out:
# ---------------------------------------------------------------------------
# JVMNotSupportedException                  Traceback (most recent call last)
# <ipython-input-7-345e5790591e> in <module>
# ----> 1 hannanum = Hannanum()
#       2
#       3 tokenized_doc = hannanum.pos(doc)
#       4 tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] == 'N'])
#       5
#
# ~\anaconda3\lib\site-packages\konlpy\tag\_hannanum.py in __init__(self, jvmpath, max_heap_size)
#      67     def __init__(self, jvmpath=None, max_heap_size=1024):
#      68         if not jpype.isJVMStarted():
# ---> 69             jvm.init_jvm(jvmpath, max_heap_size)
#      70
#      71         jhannanumJavaPackage = jpype.JPackage('kr.lucypark.jhannanum.comm')
#
# ~\anaconda3\lib\site-packages\konlpy\jvm.py in init_jvm(jvmpath, max_heap_size)
#      53     classpath = [f.format(*args) for f in folder_suffix]
#      54
# ---> 55     jvmpath = jvmpath or jpype.getDefaultJVMPath()
#      56
#      57     # NOTE: Temporary patch for Issue #76. Erase when possible.
#
# ~\anaconda3\lib\site-packages\jpype\_jvmfinder.py in getDefaultJVMPath()
#      72     else:
#      73         finder = LinuxJVMFinder()
# ---> 74     return finder.get_jvm_path()
#      75
#      76
#
# ~\anaconda3\lib\site-packages\jpype\_jvmfinder.py in get_jvm_path(self)
#     209
#     210         if jvm_notsupport_ext is not None:
# --> 211             raise jvm_notsupport_ext
#     212         raise JVMNotFoundException("No JVM shared library file ({0}) "
#     213                                    "found. Try setting up the JAVA_HOME "
#
# ~\anaconda3\lib\site-packages\jpype\_jvmfinder.py in get_jvm_path(self)
#     194                 # If found check the architecture
#     195                 if jvm:
# --> 196                     self.check(jvm)
#     197             except NotImplementedError:
#     198                 # Ignore missing implementations
#
# ~\anaconda3\lib\site-packages\jpype\_jvmfinder.py in check(self, jvm)
#     383
#     384     def check(self, jvm):
# --> 385         _checkJVMArch(jvm)
#     386
#     387     def _get_from_registry(self):
#
# ~\anaconda3\lib\site-packages\jpype\_jvmfinder.py in _checkJVMArch(jvmPath, maxsize)
#     349     if machine == IMAGE_FILE_MACHINE_I386:
#     350         if is64:
# --> 351             raise JVMNotSupportedException(
#     352                 "JVM mismatch, python is 64 bit and JVM is 32 bit.")
#     353     elif machine == IMAGE_FILE_MACHINE_IA64 or machine == IMAGE_FILE_MACHINE_AMD64:
#
# JVMNotSupportedException: JVM mismatch, python is 64 bit and JVM is 32 bit.

# %%
n_gram_range = (2, 3)

count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
candidates = count.get_feature_names_out()

print('trigram 개수 :',len(candidates))
print('trigram 다섯개만 출력 :',candidates[:5])
# Out:
# trigram 개수 : 606
# trigram 다섯개만 출력 : ['12월 총살' '12월 총살 군경' '18 실제' '18 실제 자료' '19금 판정']

# %%
# %%time
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
doc_embedding = model.encode([doc])
candidate_embeddings = model.encode(candidates)
# Out:
# Wall time: 24.8 s

# %%
top_n = 5
distances = cosine_similarity(doc_embedding, candidate_embeddings)
keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]
print(keywords)
# Out:
# ['소년 비교적 고통', '소설이길 엄마 투쟁', '이야기 과정 고통', '소년 고통 기억', '고통 한강 작가']

# %%
def mmr(doc_embedding, candidate_embeddings, words, top_n, diversity):

    # 문서와 각 키워드들 간의 유사도가 적혀있는 리스트
    word_doc_similarity = cosine_similarity(candidate_embeddings, doc_embedding)

    # 각 키워드들 간의 유사도
    word_similarity = cosine_similarity(candidate_embeddings)

    # 문서와 가장 높은 유사도를 가진 키워드의 인덱스를 추출.
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # keywords_idx = [2]
    keywords_idx = [np.argmax(word_doc_similarity)]

    # 가장 높은 유사도를 가진 키워드의 인덱스를 제외한 문서의 인덱스들
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # ==> candidates_idx = [0, 1, 3, 4, 5, 6, 7, 8, 9, 10 ... 중략 ...]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    # 최고의 키워드는 이미 추출했으므로 top_n-1번만큼 아래를 반복.
    # ex) top_n = 5라면, 아래의 loop는 4번 반복됨.
    for _ in range(top_n - 1):
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # MMR을 계산
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # keywords & candidates를 업데이트
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

# %%
mmr(doc_embedding, candidate_embeddings, candidates, top_n=5, diversity=0.8)
# Out:
# ['고통 한강 작가', '각광 제주도 추모해주길', '2차 세계대전', '사랑 가족들', '30년 군부통치하']

# %%
data['keywords']=""

# %%
data
# Out:
#      report_writer date_writer  \
# 0              박유담  2022/05/02
# 1              밤톨이  2022/04/28
# 2             명필각자  2022/04/20
# 3            maobi  2022/04/17
# 4               백석  2022/04/17
# ...            ...         ...
# 1556           꽃향유  2012/12/31
# 1557          사사로움  2010/09/27
# 1558        seonv1  2010/05/07
# 1559            검댕  2010/01/11
# 1560          두르두르  2009/12/02
#
#                                                   title     book_writer  \
# 0                                                   군주론           마키아벨리
# 1                                                   동급생          프레드 울만
# 2                                                    넛지  리처드 탈러|캐스 선스타인
# 3                   나는 매주 시체를 보러 간다 (서울대학교 최고의 ‘죽음’ 강의)             유성호
# 4       빛 속으로 (한국 문학사에서 지워진 이름. 평생을 방랑자로 산 작가 김사량의 작품집)             김사량
# ...                                                 ...             ...
# 1556                                           세계의 공익광고        카네코 히데유키
# 1557                                         귤이 탱자가된 이유            동화사랑
# 1558  Communication Technology&Society: Audience Ado...  Lin|Carolyn A.
# 1559                                            이야기 세계사         김경묵|우종익
# 1560                                         삶의 의미를 찾아서             유챙롱
#
#      book_company   book_date        date  \
# 0            현대지성  2021/07/26   2021/7/26
# 1            열린책들  2017/02/10   2017/2/10
# 2            리더스북  2018/11/23  2018/11/23
# 3          21세기북스  2019/01/23   2019/1/23
# 4            녹색광선  2021/08/15   2021/8/15
# ...           ...         ...         ...
# 1556  한국방송공사출판사업부  2022/05/03    2022/5/3
# 1557          글뿌리  2022/05/04    2022/5/4
# 1558          티메카  2022/05/04    2022/5/4
# 1559        청아출판사  2017/01/18   2017/1/18
# 1560    창작미디어(만화)  2022/05/04    2022/5/4
#
#                                             report_text keywords
# 0        마키아벨리의 군주론을 읽고21세기를 살아가고 있는 우리에게 리더의 역할은 더욱...
# 1        그는 1932년 2월에 내 삶으로 들어와서 다시는 떠나지 않았다.-『동급생』 ...
# 2           선택. 인생은 선택의 연속이다. 생활에 필요한 모든 것이 다 선택이다. ...
# 3         이 책은 법의학자이자 서울대학교 교수인 유성호 교수님의 죽음에 대한 강의를 ...
# 4        <비뚤어진 우월감>  우리는 때때로 자신의 치부로 울타리를 두르고 그 안에 갇...
# ...                                                 ...      ...
# 1556     세계의 공익 광고. 공익 광고는 꽤나 적나라하고, 충격 또한 깊게 느낄 수 있...
# 1557       봉사활동을 하러 갔다가 우연히 읽은 이 동화책. 사실 이 동화는 정말 뻔한...
# 1558     I read this book, I have some points that w...
# 1559      집에 쌓인 열 권 남짓 되는 이야기 역사책 시리즈의 첫 번째이다. 고등학교에...
# 1560     [책나눔] 니체 曰 " 왜 사는지 아는 사람은 '어떤' 고난도 이겨낼 수 있다...
#
# [1561 rows x 9 columns]
