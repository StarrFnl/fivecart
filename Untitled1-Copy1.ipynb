# %%
import numpy as np
import pandas as pd
import itertools

from konlpy.tag import Kkma, Komoran, Hannanum, Okt
from konlpy.utils import pprint
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %%
data = pd.read_csv("./fivecart_reports_2020.csv", encoding='cp949')
data.head(5)
# Out:
#   report_writer date_writer                                           title  \
# 0       한낮의 천문학  2020/12/31                                              뇌우
# 1       한낮의 천문학  2020/12/31                                 바깥은 여름 (김애란 소설)
# 2         힘내라할미  2020/12/31  꿈의 해석 (무의식의 세계를 열어젖힌 정신분석의 보고,돋을새김 푸른책장 시리즈 8)
# 3       한낮의 천문학  2020/12/31                          젊은 예술가의 초상 (세계문학전집 45)
# 4       한낮의 천문학  2020/12/31                                   창의 노동과 미디어 산업
#
#   book_writer book_company   book_date  \
# 0         차오위          민음사  2016/06/27
# 1         김애란         문학동네  2017/06/28
# 2   지그문트 프로이트         돋을새김  2014/12/20
# 3     제임스 조이스          민음사  2013/12/20
# 4  데이비드 헤스몬달프     커뮤니케이션북스  2016/03/25
#
#                                          report_text
# 0       차오위 『뇌우』  아, 누가 이런 죄를 지었는지, 누가 이런 업보를 만들었...
# 1       김애란 『바깥은 여름』  요즈음 서점을 돌면 감성적인 표지 디자인들이 먼저...
# 2     어릴 적 하루라도 꿈을 꾸지 않는 날이 없어 모든 사람들이 다 나처럼 매일 꿈...
# 3       제임스 조이스 『젊은 예술가의 초상』  『젊은 예술가의 초상』은 사회적 갈...
# 4       데이비드 헤스몬달프, 사라 베이커-『창의 노동과 미디어 산업』  편하게 돈...

# %%
#keyword cell 추가
data['keywords']=""
data
# Out:
#      report_writer date_writer  \
# 0          한낮의 천문학  2020/12/31
# 1          한낮의 천문학  2020/12/31
# 2            힘내라할미  2020/12/31
# 3          한낮의 천문학  2020/12/31
# 4          한낮의 천문학  2020/12/31
# ...            ...         ...
# 998          leeyj  2020/01/03
# 999          leeyj  2020/01/02
# 1000           다자이  2020/01/02
# 1001           다자이  2020/01/02
# 1002            수수  2020/01/02
#
#                                                title   book_writer  \
# 0                                                 뇌우           차오위
# 1                                    바깥은 여름 (김애란 소설)           김애란
# 2     꿈의 해석 (무의식의 세계를 열어젖힌 정신분석의 보고,돋을새김 푸른책장 시리즈 8)     지그문트 프로이트
# 3                             젊은 예술가의 초상 (세계문학전집 45)       제임스 조이스
# 4                                      창의 노동과 미디어 산업    데이비드 헤스몬달프
# ...                                              ...           ...
# 998                                 부분과 전체 (정식 한국어판)    베르너 하이젠베르크
# 999                                   상대성 이론과 선험적 지식      한스 라이헨바흐
# 1000                              오만과 편견 (세계문학전집 88)        제인 오스틴
# 1001                         돈키호테 (청소년 징검다리 클래식 018)   미구엘 드 세르반테스
# 1002                    알기 쉬운 블록체인 (4차 산업혁명의 핵심 기술!)  쉬밍싱|티엔잉|리지위에
#
#       book_company   book_date  \
# 0              민음사  2016/06/27
# 1             문학동네  2017/06/28
# 2             돋을새김  2014/12/20
# 3              민음사  2013/12/20
# 4         커뮤니케이션북스  2016/03/25
# ...            ...         ...
# 998   서커스(서커스출판상회)  2016/08/20
# 999       지식을만드는지식  2015/04/20
# 1000           민음사  2003/09/20
# 1001           푸른숲  2007/12/26
# 1002           북스타  2017/12/13
#
#                                             report_text keywords
# 0          차오위 『뇌우』  아, 누가 이런 죄를 지었는지, 누가 이런 업보를 만들었...
# 1          김애란 『바깥은 여름』  요즈음 서점을 돌면 감성적인 표지 디자인들이 먼저...
# 2        어릴 적 하루라도 꿈을 꾸지 않는 날이 없어 모든 사람들이 다 나처럼 매일 꿈...
# 3          제임스 조이스 『젊은 예술가의 초상』  『젊은 예술가의 초상』은 사회적 갈...
# 4          데이비드 헤스몬달프, 사라 베이커-『창의 노동과 미디어 산업』  편하게 돈...
# ...                                                 ...      ...
# 998      하이젠베르크는 원자물리학분야에서 불완전성원리를 만들었다. 원자론에 대한 대화 ...
# 999      1장 특수상대성이론은 기존의 상식을 깨는 가정을 하고 있다. 시간의 속도가 일...
# 1000        사실 오만과 편견은 영화로 먼저 접한 작품이다. 흔히 말하는 중세시대 로...
# 1001        무모하게 꿈을 쫓는 사람의 대명사 격으로 각인 되어버린 '돈 키호테'는,...
# 1002             ‘제4차 산업혁명’, ‘비트코인’, ‘핀테크’ 등등이 들려올 때...
#
# [1003 rows x 8 columns]

# %%
hannanum = Hannanum()

# %%
def mmr(doc_embedding, candidate_embeddings, words, top_n, diversity):

    # 문서와 각 키워드들 간의 유사도가 적혀있는 리스트
    word_doc_similarity = cosine_similarity(candidate_embeddings, doc_embedding)

    # 각 키워드들 간의 유사도
    word_similarity = cosine_similarity(candidate_embeddings)

    # 문서와 가장 높은 유사도를 가진 키워드의 인덱스를 추출.
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # keywords_idx = [2]
    keywords_idx = [np.argmax(word_doc_similarity)]

    # 가장 높은 유사도를 가진 키워드의 인덱스를 제외한 문서의 인덱스들
    # 만약, 2번 문서가 가장 유사도가 높았다면
    # ==> candidates_idx = [0, 1, 3, 4, 5, 6, 7, 8, 9, 10 ... 중략 ...]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    # 최고의 키워드는 이미 추출했으므로 top_n-1번만큼 아래를 반복.
    # ex) top_n = 5라면, 아래의 loop는 4번 반복됨.
    for _ in range(top_n - 1):
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # MMR을 계산
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # keywords & candidates를 업데이트
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

# %%
def extract_keyword(doc):
    tokenized_doc = hannanum.pos(doc)
    tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] == 'N'])
    
    n_gram_range = (2, 3)
    count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
    candidates = count.get_feature_names_out()
    
    model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
    doc_embedding = model.encode([doc])
    candidate_embeddings = model.encode(candidates)
    
    return mmr(doc_embedding, candidate_embeddings, candidates, top_n=5, diversity=0.8)

# %%
# %%timeit
data5['keywords'] = data5.apply(lambda row: extract_keyword(row['report_text']),axis=1)
# Out:
# <magic-timeit>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25404/2652072275.py in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', "data5['keywords'] = data5.apply(lambda row: extract_keyword(row['report_text']),axis=1)\n")
#
# ~\anaconda3\envs\cla3109\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2417             with self.builtin_trap:
#    2418                 args = (magic_arg_s, cell)
# -> 2419                 result = fn(*args, **kwargs)
#    2420             return result
#    2421
#
# ~\anaconda3\envs\cla3109\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\cla3109\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\cla3109\lib\site-packages\IPython\core\magics\execution.py in timeit(self, line, cell, local_ns)
#    1182                     break
#    1183
# -> 1184         all_runs = timer.repeat(repeat, number)
#    1185         best = min(all_runs) / number
#    1186         worst = max(all_runs) / number
#
# ~\anaconda3\envs\cla3109\lib\timeit.py in repeat(self, repeat, number)
#     203         r = []
#     204         for i in range(repeat):
# --> 205             t = self.timeit(number)
#     206             r.append(t)
#     207         return r
#
# ~\anaconda3\envs\cla3109\lib\site-packages\IPython\core\magics\execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# ~\anaconda3\envs\cla3109\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8831             kwargs=kwargs,
#    8832         )
# -> 8833         return op.apply().__finalize__(self, method="apply")
#    8834
#    8835     def applymap(
#
# ~\anaconda3\envs\cla3109\lib\site-packages\pandas\core\apply.py in apply(self)
#     725             return self.apply_raw()
#     726
# --> 727         return self.apply_standard()
#     728
#     729     def agg(self):
#
# ~\anaconda3\envs\cla3109\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     849
#     850     def apply_standard(self):
# --> 851         results, res_index = self.apply_series_generator()
#     852
#     853         # wrap results
#
# ~\anaconda3\envs\cla3109\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     865             for i, v in enumerate(series_gen):
#     866                 # ignore SettingWithCopy here in case the user mutates
# --> 867                 results[i] = self.f(v)
#     868                 if isinstance(results[i], ABCSeries):
#     869                     # If we have a view on v, we need to make a copy because
#
# <magic-timeit> in <lambda>(row)
#
# ~\AppData\Local\Temp/ipykernel_25404/2306891630.py in extract_keyword(doc)
#       7     candidates = count.get_feature_names_out()
#       8
# ----> 9     model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
#      10     doc_embedding = model.encode([doc])
#      11     candidate_embeddings = model.encode(candidates)
#
# ~\anaconda3\envs\cla3109\lib\site-packages\sentence_transformers\SentenceTransformer.py in __init__(self, model_name_or_path, modules, device, cache_folder, use_auth_token)
#      92
#      93             if os.path.exists(os.path.join(model_path, 'modules.json')):    #Load as SentenceTransformer model
# ---> 94                 modules = self._load_sbert_model(model_path)
#      95             else:   #Load with AutoModel
#      96                 modules = self._load_auto_model(model_path)
#
# ~\anaconda3\envs\cla3109\lib\site-packages\sentence_transformers\SentenceTransformer.py in _load_sbert_model(self, model_path)
#     829         for module_config in modules_config:
#     830             module_class = import_from_string(module_config['type'])
# --> 831             module = module_class.load(os.path.join(model_path, module_config['path']))
#     832             modules[module_config['name']] = module
#     833
#
# ~\anaconda3\envs\cla3109\lib\site-packages\sentence_transformers\models\Transformer.py in load(input_path)
#     135         with open(sbert_config_path) as fIn:
#     136             config = json.load(fIn)
# --> 137         return Transformer(model_name_or_path=input_path, **config)
#     138
#     139
#
# ~\anaconda3\envs\cla3109\lib\site-packages\sentence_transformers\models\Transformer.py in __init__(self, model_name_or_path, max_seq_length, model_args, cache_dir, tokenizer_args, do_lower_case, tokenizer_name_or_path)
#      27
#      28         config = AutoConfig.from_pretrained(model_name_or_path, **model_args, cache_dir=cache_dir)
# ---> 29         self._load_model(model_name_or_path, config, cache_dir)
#      30
#      31         self.tokenizer = AutoTokenizer.from_pretrained(tokenizer_name_or_path if tokenizer_name_or_path is not None else model_name_or_path, cache_dir=cache_dir, **tokenizer_args)
#
# ~\anaconda3\envs\cla3109\lib\site-packages\sentence_transformers\models\Transformer.py in _load_model(self, model_name_or_path, config, cache_dir)
#      47             self._load_t5_model(model_name_or_path, config, cache_dir)
#      48         else:
# ---> 49             self.auto_model = AutoModel.from_pretrained(model_name_or_path, config=config, cache_dir=cache_dir)
#      50
#      51     def _load_t5_model(self, model_name_or_path, config, cache_dir):
#
# ~\anaconda3\envs\cla3109\lib\site-packages\transformers\models\auto\auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     444         elif type(config) in cls._model_mapping.keys():
#     445             model_class = _get_model_class(config, cls._model_mapping)
# --> 446             return model_class.from_pretrained(pretrained_model_name_or_path, *model_args, config=config, **kwargs)
#     447         raise ValueError(
#     448             f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#
# ~\anaconda3\envs\cla3109\lib\site-packages\transformers\modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    2057                 torch.set_default_dtype(dtype_orig)
#    2058
# -> 2059             model, missing_keys, unexpected_keys, mismatched_keys, error_msgs = cls._load_pretrained_model(
#    2060                 model,
#    2061                 state_dict,
#
# ~\anaconda3\envs\cla3109\lib\site-packages\transformers\modeling_utils.py in _load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage)
#    2209                 ignore_mismatched_sizes,
#    2210             )
# -> 2211             error_msgs = _load_state_dict_into_model(model_to_load, state_dict, start_prefix)
#    2212         else:
#    2213             # Sharded checkpoint or whole but low_cpu_mem_usage==True
#
# ~\anaconda3\envs\cla3109\lib\site-packages\transformers\modeling_utils.py in _load_state_dict_into_model(model_to_load, state_dict, start_prefix)
#     458                 load(child, prefix + name + ".")
#     459
# --> 460     load(model_to_load, prefix=start_prefix)
#     461
#     462     return error_msgs
#
# ~\anaconda3\envs\cla3109\lib\site-packages\transformers\modeling_utils.py in load(module, prefix)
#     456         for name, child in module._modules.items():
#     457             if child is not None:
# --> 458                 load(child, prefix + name + ".")
#     459
#     460     load(model_to_load, prefix=start_prefix)
#
# ~\anaconda3\envs\cla3109\lib\site-packages\transformers\modeling_utils.py in load(module, prefix)
#     456         for name, child in module._modules.items():
#     457             if child is not None:
# --> 458                 load(child, prefix + name + ".")
#     459
#     460     load(model_to_load, prefix=start_prefix)
#
# ~\anaconda3\envs\cla3109\lib\site-packages\transformers\modeling_utils.py in load(module, prefix)
#     452                     module._load_from_state_dict(*args)
#     453         else:
# --> 454             module._load_from_state_dict(*args)
#     455
#     456         for name, child in module._modules.items():
#
# ~\anaconda3\envs\cla3109\lib\site-packages\torch\nn\modules\module.py in _load_from_state_dict(self, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs)
#    1411                 try:
#    1412                     with torch.no_grad():
# -> 1413                         param.copy_(input_param)
#    1414                 except Exception as ex:
#    1415                     error_msgs.append('While copying the parameter named "{}", '
#
# KeyboardInterrupt:

# %%
data5=data.head(5)

# %%
data5
